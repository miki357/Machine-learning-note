# %% [markdown]
# # CH4
# # APPLICATIONS OF MACHINE LEARNING TO ECONOMICS AND FINANCE

# %%
% autosave 120

# %% [markdown]
# ## Plot
# 單一變數（一維變數）：
# - 類別型資料：柱狀圖（又稱長條圖）、圓餅圖
# - 連續型資料：直方圖、箱型圖。
#
# 二維變數：
# - 「類別型資料」對「類別型資料」：柱狀圖（又稱長條圖）
# - 「類別型資料」對「連續型資料」：直方圖或箱型圖
# - 「連續型資料」對「連續型資料」：散佈圖scatter plot

# %% [markdown]
# ## Python資料視覺化主要有三大套件：
# - Seaborn
# - Matplotlib
# - Plotly

# %% [markdown]
# ## Pandas Built-in Data Visualization

# %% [markdown]
# ### Plot Types
# * df.plot.area: 地區圖
# * df.plot.barh: 水平長條圖
# * df.plot.density: 機率密度圖???
# * df.plot.hist: 直方圖
# * df.plot.line: 折線圖
# * df.plot.scatter: 散佈圖
# * df.plot.bar: 垂直長條圖
# * df.plot.box: 箱形圖
# * df.plot.hexbin: 六邊箱圖
# * df.plot.kde: 核密度估計圖
# * df.plot.pie: 圓餅圖

# %%
import numpy as np
import pandas as pd

# %%
# Use this line to see plots in the notebook
# %matplotlib inline

# %% [markdown]
# **Fake data csv files**

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('data/df1')
df2 = pd.read_csv('data/df2')

# %%
df1.head()
# Out:
#    Unnamed: 0         A         B         C         D
# 0  2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1  2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2  2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3  2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4  2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2.head()

# %%
df1['A'].hist()

# %%
df1['A'].plot.hist(bins=50)

# %% [markdown]
# **Barplot**長條圖 <br/>
# DataFrame裡的列索引會在x軸，欄索引鍵會在y軸。

# %%
df2.plot.bar()

# %%
# alternative
df2.plot(kind='bar')

# %%
df2.plot.bar(stacked=True)

# %%
df2['a'].plot(kind='bar')

# %%
df2['a'].sort_values(ascending=False).plot(kind='bar')

# %%
df2['a'].plot(kind='barh')

# %% [markdown]
# **Pie Chart**圓餅圖 <br/>
# 當資料用圓餅圖呈現時，可以看出它占總體的百分比。

# %%
df2['b'].plot(kind='pie')

# %% [markdown]
# **BoxPlot**箱形圖 <br/>
# 中間箱子的兩端為第一四分位數（涵蓋25%之資料，Q1）與第三四分位數（涵蓋75%之資料，Q3），而箱子中間線為中位數（median）。<br/>
# 換言之，箱子涵蓋50%的資料。箱型外的圓圈，則是被判定成「異常值」。

# %%
df2.plot.box()

# %% [markdown]
# **Kernel Density Estimation plot (KDE)**

# %%
df2['a'].plot.kde()

# %% [markdown]
# **Line Plot**折線圖

# %%
df1.plot.line(y='B',figsize=(12,3))

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.groupby(['smoker','sex']).size().unstack(1).plot(kind='bar')   #直條圖

# %%
tips.groupby(['smoker','sex']).size().unstack(1).plot(kind='barh')   #橫條圖

# %%
tips.groupby('sex')['total_bill'].plot(kind='hist', bins=30, alpha=0.5, legend=True) #alpha 是透明度的參數設定。
# Out:
# sex
# Male      AxesSubplot(0.125,0.125;0.775x0.755)
# Female    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: total_bill, dtype: object

# %%
tips.boxplot(column='total_bill',by='sex')

# %% [markdown]
# **Scatter Plot**散佈圖

# %%
df1.plot.scatter(x='A',y='B')

# %%
# color based off another column value
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')

# %%
# color based off another column value
df1.plot.scatter(x='A',y='C',c='D',cmap='coolwarm')      #換資料練習

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*200)
# Out:
# C:\Users\Ching Wen\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# **Hexagonal Bin Plot**六邊箱圖(直譯)

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='Oranges')

# %% [markdown]
# For all the colormaps, check out: http://matplotlib.org/users/colormaps.html

# %% [markdown]
# ## Seaborn
# seaborn為python繪圖函式庫，以matplotlib為基礎封裝了許多實用的統計圖表，相較於matplotlib，seaborn的預設圖形更為好看，語法更為簡潔，並且良好的支援了pandas函式庫。 <br/>
#
# **優點：**
# 1. 畫圖指令非常簡單
# 2. 圖案好看 <br/>
#
# **缺點：**
# 1. 雖然99%的使用上都沒問題，但有些進階的圖案很難畫或是沒辦法畫（可用matplot互補）

# %% [markdown]
# ### Plot Types
# * factorplot 只要設定參數kind就可以以下各類圖表, 未將改名為catplot
# * boxplot
# * violinplot 小提琴圖
# * stripplot  分布散點圖
# * swarmplot  ???
# * barplot
# * countplot  計數直方圖
# * heatmap    熱區圖
# * distplot   ???
# * jointplot  ???
# * pairplot   散點圖矩陣
# * rugplot    地毯圖
# * kdeplot    核密度圖

# %%
sns.catplot(x='sex',y='total_bill',data=tips, kind="bar")

# %% [markdown]
# **BarPlot**

# %%
sns.barplot(x='sex',y='total_bill',data=tips)

# %% [markdown]
# **CountPlot**

# %%
sns.countplot(x='sex',data=tips)

# %% [markdown]
# Use matplotlib's **plt.figure(figsize=(width,height))** to change the size of most seaborn plots.

# %%
plt.figure(figsize=(12,3))
sns.countplot(x='sex',data=tips)

# %% [markdown]
# **BoxPlot**

# %%
sns.boxplot(x="day", y="total_bill", data=tips,palette='rainbow')

# %%
sns.boxplot(x="day", y="total_bill", hue="smoker",data=tips, palette="coolwarm")

# %% [markdown]
# **HeatMap**

# %%
#相關係數
# Matrix form for correlation data
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr())

# %%
sns.heatmap(tips.corr(),cmap='coolwarm',annot=True)

# %% [markdown]
# **distplot**

# %%
sns.distplot(tips['total_bill']) # Safe to ignore warnings

# %%
sns.distplot(tips['total_bill'],kde=False,bins=30)

# %% [markdown]
# **jointplot**

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='scatter')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %% [markdown]
# **pairplot**

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue='sex',palette='coolwarm')

# %% [markdown]
# **lmplot**

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex')

# %%
sns.lmplot(x="total_bill", y="tip", row="sex", col="time",data=tips)

# %% [markdown]
# ## Matplotlib
# **優點：**
# 1. 相較於其他視覺化套件，matplot算是最歷史悠久，因此有很多的教學文章或是範例可參考
# 2. 畫圖功能最齊全，基本上沒什麼圖表畫不出來的 <br/>
#
# **缺點:**
# 1. 圖表不好看(新版的matplot其實也算好看，尤其在style功能出來之後可以自行切換圖表的風格)
# 2. 畫圖指令複雜
#
# official Matplotlib web page: http://matplotlib.org/ <br/>
#
#
# **Install with either:**
#
#    `conda install matplotlib`
#
# or
#
#    `pip install matplotlib`

# %%
import matplotlib.pyplot as plt

# %%
x=[5,4,3,2,1]
y=[1,2,3,4,5]
plt.plot(x,y,color='blue')
plt.show()

# %%
Image(filename = "img/para.png", width = 600, height = 800)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-c3c4f2cde658> in <module>()
# ----> 1 Image(filename = "img/para.png", width = 600, height = 800)
#
# NameError: name 'Image' is not defined

# %%
'''線條樣式'''
Image(filename = "img/lineForm.JPG", width = 225, height = 150)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-2b76f4d1649f> in <module>()
#       1 '''線條樣式'''
# ----> 2 Image(filename = "img/lineForm.JPG", width = 225, height = 150)
#
# NameError: name 'Image' is not defined

# %% [markdown]
# **圖形色彩除了使用上表的字元當作參數值之外，也可以使用電腦系統的十六進制表示法，也就是一般RGB三原色模式的參數值。**

# %%
# alternative
plt.plot(x,y,color='#0000ff')
plt.show()

# %%
plt.plot(x,y,'o')

# %%
plt.plot(x,y,'o',markersize=15)

# %%
plt.plot(x,y,color='g',linestyle='dashed',markeredgecolor='r',marker='+')

# %%
Image(filename = "img/axis1.jpg", width = 600, height = 800)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-15f5e6f9c00f> in <module>()
# ----> 1 Image(filename = "img/axis1.jpg", width = 600, height = 800)
#
# NameError: name 'Image' is not defined

# %%
Image(filename = "img/axis2.jpg", width = 600, height = 800)

# %%
x=np.array([5,4,3,2,1])
y=pow(x,3)
plt.axis([1,6,1,150])
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,label='y = x ** 3')
plt.legend()

# %%
'''圖例位置參數設定'''
Image(filename = "img/legend.JPG", width = 225, height = 150)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-e84cd46eefa7> in <module>()
#       1 '''圖例位置參數設定'''
# ----> 2 Image(filename = "img/legend.JPG", width = 225, height = 150)
#
# NameError: name 'Image' is not defined

# %%
plt.plot(x,y,label='y = x ** 3')
plt.legend(loc=4,shadow=True)

# %%
z=pow(x,4)
w=pow(x,5)
plt.figure(figsize=(8,6))
plt.plot(x,y)
plt.plot(x,z)
plt.plot(x,w)
plt.title("The result")
plt.text(4.5,200,'x**3')
plt.text(4,400,'x**4')
plt.text(3.5,900,'x**5')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-b1f5a57d1d92> in <module>()
# ----> 1 z=pow(x,4)
#       2 w=pow(x,5)
#       3 plt.figure(figsize=(8,6))
#       4 plt.plot(x,y)
#       5 plt.plot(x,z)
#
# TypeError: unsupported operand type(s) for ** or pow(): 'list' and 'int'

# %%
plt.subplots()
plt.axes()
plt.axes([0.65,0.65,0.2,0.2])

# %% [markdown]
# # Good Job!

# %% [markdown]
# # Exercise
# 使用TITANIC的資料繪圖

# %%
A=sns.load_dataset('titanic')
A.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# **繪製age的直方圖, 區間值設為30**

# %%
A['age'].plot.hist(bins=30)

# %% [markdown]
# **製作survived和sex的交叉表**

# %%
A.corr()
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %% [markdown]
# **將結果製成圖**

# %%
A.groupby(['survived','sex']).size().unstack(1).plot(kind='bar')

# %% [markdown]
# **製作survived和age的圖。將依存活與否分成兩組，再將兩組的資料分別用直方圖來呈現。畫在同一格表格上**

# %%
A.groupby('survived')['age'].plot(kind='hist', bins=30, alpha=0.5, legend=True)
# Out:
# survived
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: age, dtype: object

# %% [markdown]
# **用箱型圖來呈現**

# %%
A.boxplot(column='age',by='survived')

# %% [markdown]
# **自由發揮, 至少再繪製3個不同的圖,並解釋其用意**

# %%
A.groupby(['alive','who']).size().unstack(1).plot(kind='bar')    #活著的人的(男人女人小孩)

# %%
A=sns.load_dataset('titanic')
A.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 11         1       1  female  58.0      0      0  26.5500        S   First
# 12         0       3    male  20.0      0      0   8.0500        S   Third
# 13         0       3    male  39.0      1      5  31.2750        S   Third
# 14         0       3  female  14.0      0      0   7.8542        S   Third
# 15         1       2  female  55.0      0      0  16.0000        S  Second
# 16         0       3    male   2.0      4      1  29.1250        Q   Third
# 17         1       2    male   NaN      0      0  13.0000        S  Second
# 18         0       3  female  31.0      1      0  18.0000        S   Third
# 19         1       3  female   NaN      0      0   7.2250        C   Third
#
#       who  adult_male deck  embark_town alive  alone
# 0     man        True  NaN  Southampton    no  False
# 1   woman       False    C    Cherbourg   yes  False
# 2   woman       False  NaN  Southampton   yes   True
# 3   woman       False    C  Southampton   yes  False
# 4     man        True  NaN  Southampton    no   True
# 5     man        True  NaN   Queenstown    no   True
# 6     man        True    E  Southampton    no   True
# 7   child       False  NaN  Southampton    no  False
# 8   woman       False  NaN  Southampton   yes  False
# 9   child       False  NaN    Cherbourg   yes  False
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True
# 12    man        True  NaN  Southampton    no   True
# 13    man        True  NaN  Southampton    no  False
# 14  child       False  NaN  Southampton    no   True
# 15  woman       False  NaN  Southampton   yes   True
# 16  child       False  NaN   Queenstown    no  False
# 17    man        True  NaN  Southampton   yes   True
# 18  woman       False  NaN  Southampton    no  False
# 19  woman       False  NaN    Cherbourg   yes   True

# %%
A.groupby(['sibsp','sex']).size().unstack(1).plot(kind='bar')    #兄弟姐妹的數量去分辨性別

# %%
A.groupby(['pclass'])['fare'].describe()
# Out:
#         count       mean        std  min       25%      50%   75%       max
# pclass
# 1       216.0  84.154687  78.380373  0.0  30.92395  60.2875  93.5  512.3292
# 2       184.0  20.662183  13.417399  0.0  13.00000  14.2500  26.0   73.5000
# 3       491.0  13.675550  11.778142  0.0   7.75000   8.0500  15.5   69.5500

# %%
A.fare.mean()
# Out:
# 32.2042079685746

# %%
test=A.groupby(['pclass'])['fare'].mean()

# %%
test.plot(kind='bar')    #每個艙等的票價平均
